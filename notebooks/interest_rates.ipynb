# %% [markdown]
# # US Interest Rates

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import datetime

# %%
fred = pd.read_csv('../price_ranges/interest_rates.csv')
fred
# Out:
#      observation_date   DFF
# 0          2016-01-01  0.20
# 1          2016-01-02  0.20
# 2          2016-01-03  0.20
# 3          2016-01-04  0.36
# 4          2016-01-05  0.36
# ...               ...   ...
# 3648       2025-12-27  3.64
# 3649       2025-12-28  3.64
# 3650       2025-12-29  3.64
# 3651       2025-12-30  3.64
# 3652       2025-12-31  3.64
#
# [3653 rows x 2 columns]

# %%
index = fred.iloc[:, 0]

# %%
fred.index = index

# %%
fred.drop('observation_date', axis=1, inplace=True)

fred.head()
# Out:
#                    DFF
# observation_date
# 2016-01-01        0.20
# 2016-01-02        0.20
# 2016-01-03        0.20
# 2016-01-04        0.36
# 2016-01-05        0.36

# %%
fred.plot(kind='line',
          xlabel='Date',
          ylabel='Federal Funds Rate (%)',
          title='Federal Funds Rate from 2020 - 2025',figsize=(12,6))
plt.grid(alpha=.4)
plt.show()

# %%
fred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3653 entries, 2016-01-01 to 2025-12-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DFF     3653 non-null   float64
# dtypes: float64(1)
# memory usage: 186.1+ KB

# %%
fred.to_parquet('../price_ranges/federal_funds_rate_ammended.parquet')
